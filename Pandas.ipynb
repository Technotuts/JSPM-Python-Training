# %%
import pandas as pd

# %%
df = pd.read_csv("G:/train.csv")
df1 = pd.read_csv('G:/test.csv')

# %%
df.info()
#to get the information of all the rows in a dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()

# to preview the statistical information of all columns in a dataset
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
#to find the column names in the dataset
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(20)
#to view the first few records in a dataset. the default records displayed is 5. if we need more records we need to mention the value in the parenthesis
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.tail()
#to view the last few records in a dataset. the default records displayed is 5. if we need more records we need to mention the value in the parenthesis
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# to find the number of rows and columns
# Out:
# (891, 12)

# %%
data = pd.concat((df, df1), axis = 0)
#Merging two dataframes. Axis = 0 would mean merging on rows
#Axis = 1 means merging through columns

# %%
data.shape
# Out:
# (1309, 12)

# %%
df['Survived'].value_counts()

#Counting the unique values in column
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.count()
#counting the number of rows in one or more columns
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.isnull().sum()
#finding null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Survived'].unique()
#finding unique values
# Out:
# array([0, 1], dtype=int64)

# %%
new_df = df.drop(columns=(['Name', 'PassengerId']), axis = 0)
#dropping columns

# %%
new_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
df.loc[0:10]
#iterating through data
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %%
df[df['Survived']==0]
#Subsetting data with one condition
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[['PassengerId', 'Parch']][(df['Survived']==0) & (df['Sex']=='female')]
#subsetting data with multiple conditions
#for and operator we use the & symbol
#for Or operator we | symbol
# Out:
#      PassengerId  Parch
# 14            15      0
# 18            19      0
# 24            25      1
# 38            39      0
# 40            41      0
# ..           ...    ...
# 854          855      0
# 863          864      2
# 882          883      0
# 885          886      5
# 888          889      2
#
# [81 rows x 2 columns]

# %%
df2 = df.copy()
#to create a new copy of the dataset

# %%
df['SibSp'].astype('object')
#this is used to change the datatype for all records in a particular column
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: object

# %%
#df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).count().sort_values(by='Survived', ascending=False)

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df[df['Age'] <= 29]

# %%
import numpy as np
data = pd.DataFrame(
    {
        "a": np.random.choice(["x", "y", "z"], 1000),
        "b": np.random.choice(["e", "f", "g"], 1000),
        "c": np.random.randn(1000),
        "d": np.random.randn(1000) - 1,
    },
)


data.plot.hist(by=["a", "b"], figsize=(10, 5));

# %%
data = pd.Series(np.random.randn(1000))

data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
df['Fare'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot.box()
# Out:
# <Axes: >

# %%
df['Age'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df['Survived'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

df.plot.area();

# %%
df.plot.area(stacked=False);

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])

df["species"] = pd.Categorical(
    ["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] * 10
)


df.plot.scatter(x="a", y="b");

# %%
ax = df.plot.scatter(x="a", y="b", color="DarkBlue", label="Group 1")

df.plot.scatter(x="c", y="d", color="DarkGreen", label="Group 2", ax=ax);

# %%
data1 = pd.read_csv('G:\\country_info.txt', sep = '|')

# %%
data1.head()
# Out:
#           Country    Capital  CC  CC3     IAC   TimeZone        Currency
# 0     Afghanistan      Kabul  AF  AFG     +93  UTC+04:30  Afghan afghani
# 1   Aland Islands  Mariehamn  AX  ALA    +358  UTC+02:00            Euro
# 2         Albania     Tirana  AL  ALB    +355  UTC+01:00    Albanian lek
# 3         Algeria    Algiers  DZ  DZA    +213        UTC  Algerian dinar
# 4  American Samoa  Pago Pago  AS  ASM  +1 684  UTC-11:00             NaN
